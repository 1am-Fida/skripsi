# %% [markdown]
# <a href="https://colab.research.google.com/github/1am-Fida/skripsi/blob/main/rf_ar_es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Install

# %%
pip install dysts
# Out:
# Collecting dysts
#   Downloading dysts-0.1-py3-none-any.whl (93.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 MB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from dysts) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from dysts) (1.10.1)
# Installing collected packages: dysts
# Successfully installed dysts-0.1

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (0.13.5)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (23.1)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->statsmodels) (2022.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
pip install nolds
# Out:
# Collecting nolds
#   Downloading nolds-0.5.2-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from nolds) (1.22.4)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from nolds) (0.18.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nolds) (67.7.2)
# Installing collected packages: nolds
# Successfully installed nolds-0.5.2

# %%
pip install darts
# Out:
# Collecting darts
#   Downloading darts-0.24.0-py3-none-any.whl (693 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 693.9/693.9 kB 17.6 MB/s eta 0:00:00
# Collecting catboost>=1.0.6 (from darts)
#   Downloading catboost-1.2-cp310-cp310-manylinux2014_x86_64.whl (98.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: holidays>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from darts) (0.27.1)
# Requirement already satisfied: joblib>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from darts) (1.2.0)
# Requirement already satisfied: lightgbm>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from darts) (3.3.5)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from darts) (3.7.1)
# Collecting nfoursid>=1.0.0 (from darts)
#   Downloading nfoursid-1.0.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from darts) (1.22.4)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from darts) (1.5.3)
# Collecting pmdarima>=1.8.0 (from darts)
#   Downloading pmdarima-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 69.1 MB/s eta 0:00:00
# Requirement already satisfied: prophet>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from darts) (1.1.4)
# Collecting pyod>=0.9.5 (from darts)
#   Downloading pyod-1.1.0.tar.gz (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 15.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from darts) (2.27.1)
# Requirement already satisfied: scikit-learn>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from darts) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from darts) (1.10.1)
# Collecting shap>=0.40.0 (from darts)
#   Downloading shap-0.41.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 kB 18.5 MB/s eta 0:00:00
# Collecting statsforecast>=1.4 (from darts)
#   Downloading statsforecast-1.5.0-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from darts) (0.13.5)
# Collecting tbats>=1.1.0 (from darts)
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.60.0 in /usr/local/lib/python3.10/dist-packages (from darts) (4.65.0)
# Requirement already satisfied: xarray>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from darts) (2022.12.0)
# Requirement already satisfied: xgboost>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from darts) (1.7.6)
# Collecting pytorch-lightning>=1.5.0 (from darts)
#   Downloading pytorch_lightning-2.0.4-py3-none-any.whl (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.2/721.2 kB 33.2 MB/s eta 0:00:00
# Collecting tensorboardX>=2.1 (from darts)
#   Downloading tensorboardX-2.6.1-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from darts) (2.0.1+cu118)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost>=1.0.6->darts) (0.20.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost>=1.0.6->darts) (5.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost>=1.0.6->darts) (1.16.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays>=0.11.1->darts) (2.8.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from lightgbm>=3.2.0->darts) (0.40.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->darts) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->darts) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->darts) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->darts) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->darts) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->darts) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->darts) (3.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->darts) (2022.7.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima>=1.8.0->darts) (0.29.35)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima>=1.8.0->darts) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima>=1.8.0->darts) (67.7.2)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet>=1.1.1->darts) (1.1.0)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from prophet>=1.1.1->darts) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from prophet>=1.1.1->darts) (2.4.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet>=1.1.1->darts) (5.12.0)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.10/dist-packages (from pyod>=0.9.5->darts) (0.56.4)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.5.0->darts) (6.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.5.0->darts) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning>=1.5.0->darts)
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 35.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.5.0->darts) (4.6.3)
# Collecting lightning-utilities>=0.7.0 (from pytorch-lightning>=1.5.0->darts)
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->darts) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->darts) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->darts) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.1->darts) (3.1.0)
# Collecting slicer==0.0.7 (from shap>=0.40.0->darts)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap>=0.40.0->darts) (2.2.1)
# Collecting plotly-resampler (from statsforecast>=1.4->darts)
#   Downloading plotly_resampler-0.8.3.2.tar.gz (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fugue>=0.8.1 (from statsforecast>=1.4->darts)
#   Downloading fugue-0.8.5-py3-none-any.whl (273 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.6/273.6 kB 27.1 MB/s eta 0:00:00
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.0->darts) (0.5.3)
# Collecting protobuf>=4.22.3 (from tensorboardX>=2.1->darts)
#   Downloading protobuf-4.23.3-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->darts) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->darts) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->darts) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->darts) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->darts) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->darts) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->darts) (16.0.6)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.10/dist-packages (from convertdate>=2.1.2->prophet>=1.1.1->darts) (0.5.12)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (3.8.4)
# Collecting triad>=0.9.0 (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading triad-0.9.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 6.3 MB/s eta 0:00:00
# Collecting adagio>=0.2.4 (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading adagio-0.2.4-py3-none-any.whl (26 kB)
# Requirement already satisfied: pyarrow>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from fugue>=0.8.1->statsforecast>=1.4->darts) (9.0.0)
# Collecting qpd>=0.4.3 (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading qpd-0.4.3-py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.1/169.1 kB 19.2 MB/s eta 0:00:00
# Collecting fugue-sql-antlr>=0.1.6 (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading fugue-sql-antlr-0.1.6.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.6/154.6 kB 18.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sqlglot (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading sqlglot-16.8.1-py3-none-any.whl (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 29.2 MB/s eta 0:00:00
# Requirement already satisfied: ephem>=3.7.5.3 in /usr/local/lib/python3.10/dist-packages (from LunarCalendar>=0.0.9->prophet>=1.1.1->darts) (4.1.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51->pyod>=0.9.5->darts) (0.39.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->darts) (2.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost>=1.0.6->darts) (8.2.2)
# Collecting dash<3.0.0,>=2.2.0 (from plotly-resampler->statsforecast>=1.4->darts)
#   Downloading dash-2.11.1-py3-none-any.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 84.4 MB/s eta 0:00:00
# Collecting jupyter-dash>=0.4.2 (from plotly-resampler->statsforecast>=1.4->darts)
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Collecting orjson<4.0.0,>=3.8.0 (from plotly-resampler->statsforecast>=1.4->darts)
#   Downloading orjson-3.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.0/137.0 kB 4.8 MB/s eta 0:00:00
# Collecting trace-updater>=0.0.8 (from plotly-resampler->statsforecast>=1.4->darts)
#   Downloading trace_updater-0.0.9.1-py3-none-any.whl (185 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 22.0 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->darts) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (1.3.1)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts) (2.2.5)
# Collecting Werkzeug<2.3.0 (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts)
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 25.1 MB/s eta 0:00:00
# Collecting dash-html-components==2.0.0 (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0 (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0 (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting retrying (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting ansi2html (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts)
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts) (1.5.6)
# Collecting antlr4-python3-runtime<4.12,>=4.11.1 (from fugue-sql-antlr>=0.1.6->fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading antlr4_python3_runtime-4.11.1-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (7.34.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (5.5.6)
# Collecting fs (from triad>=0.9.0->fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts) (8.1.3)
# Requirement already satisfied: appdirs~=1.4.3 in /usr/local/lib/python3.10/dist-packages (from fs->triad>=0.9.0->fugue>=0.8.1->statsforecast>=1.4->darts) (1.4.4)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.2.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (6.3.1)
# Collecting jedi>=0.16 (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.8 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.2.6)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (5.3.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (23.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (3.7.0)
# Building wheels for collected packages: pyod, plotly-resampler, fugue-sql-antlr
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-1.1.0-py3-none-any.whl size=185331 sha256=57fff6809c288521eddc60a6f0cdb8d7beddd32b7039ad938edc0a182c4137a2
#   Stored in directory: /root/.cache/pip/wheels/36/8e/e2/e932956b10b843eb6be9eefa70b5c1bee7b561be14c423b136
#   Building wheel for plotly-resampler (pyproject.toml) ... done
#   Created wheel for plotly-resampler: filename=plotly_resampler-0.8.3.2-cp310-cp310-manylinux_2_31_x86_64.whl size=75235 sha256=49813adf86f742b48bad3c8eac9c1c3fd840586a5e015f023b6bcf62ef3dfaf3
#   Stored in directory: /root/.cache/pip/wheels/a9/19/e2/ec856d98cf9b617511fff0abae1dfed5bf1f6093ce65126b45
#   Building wheel for fugue-sql-antlr (setup.py) ... done
#   Created wheel for fugue-sql-antlr: filename=fugue_sql_antlr-0.1.6-py3-none-any.whl size=158049 sha256=fd1bdd6dee346bcc9ea47c54737bc62f38c4081a639ab0a6c784877ca9991e96
#   Stored in directory: /root/.cache/pip/wheels/c8/54/a1/b294b8b33c6107946b5720b3acb1fce07b97bbbc9677a501ce
# Successfully built pyod plotly-resampler fugue-sql-antlr
# Installing collected packages: trace-updater, sqlglot, dash-table, dash-html-components, dash-core-components, antlr4-python3-runtime, Werkzeug, slicer, retrying, protobuf, orjson, lightning-utilities, jedi, fs, ansi2html, tensorboardX, triad, shap, pyod, nfoursid, dash, catboost, pmdarima, jupyter-dash, fugue-sql-antlr, adagio, tbats, qpd, plotly-resampler, fugue, statsforecast, torchmetrics, pytorch-lightning, darts
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.3.6
#     Uninstalling Werkzeug-2.3.6:
#       Successfully uninstalled Werkzeug-2.3.6
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed Werkzeug-2.2.3 adagio-0.2.4 ansi2html-1.8.0 antlr4-python3-runtime-4.11.1 catboost-1.2 darts-0.24.0 dash-2.11.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 fs-2.4.16 fugue-0.8.5 fugue-sql-antlr-0.1.6 jedi-0.18.2 jupyter-dash-0.4.2 lightning-utilities-0.9.0 nfoursid-1.0.1 orjson-3.9.1 plotly-resampler-0.8.3.2 pmdarima-2.0.3 protobuf-4.23.3 pyod-1.1.0 pytorch-lightning-2.0.4 qpd-0.4.3 retrying-1.3.4 shap-0.41.0 slicer-0.0.7 sqlglot-16.8.1 statsforecast-1.5.0 tbats-1.1.3 tensorboardX-2.6.1 torchmetrics-0.11.4 trace-updater-0.0.9.1 triad-0.9.0

# %%
import torch, numpy as np

# Kalau saya sukanya cek versi dan apakah PyTorch (atau tensorflow) sudah dapat mengakses GPU atau belum
print("Using Numpy and Pytorch versions = {}, {}".format(np.__version__, torch.__version__))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device, end=', ')
if device.type == 'cuda': #Additional Info when using cuda
    print(torch.cuda.get_device_name(0))
    print('Currently Memory Allocated, Cached =', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB, ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using Numpy and Pytorch versions = 1.22.4, 2.0.1+cu118
# Using device: cpu,

# %% [markdown]
# ### Data

# %%
from dysts.datasets import load_dataset
import pandas as pd
import darts
import matplotlib.pyplot as plt
from darts.models import ARIMA, RandomForest, ExponentialSmoothing,RegressionEnsembleModel
from darts.metrics import mape, smape, rmse
import warnings; warnings.simplefilter('ignore'); warnings.filterwarnings('ignore', module='darts'); warnings.filterwarnings('ignore', module='pandas')
import sys
from darts import metrics

np.random.seed(1)

# %%
data = 'Lorenz84'
train_ = load_dataset(subsets="train", data_format="pandas", univariate=True).loc[data]
test_ = load_dataset(subsets="test", data_format="pandas", univariate=True).loc[data]

# %%
df = pd.concat([train_, test_], ignore_index=True) # , keys=["Train", "Test", "Validation"]
df.drop(['id'], axis=1, inplace=True)
df = df[['values']]#sol[['time', 'values_0']]

# %%
df.head()
# Out:
#      values
# 0  0.334791
# 1  0.541438
# 2  0.774878
# 3  1.016596
# 4  1.234661

# %% [markdown]
# ### exploratory data analys

# %%
(pd.concat([train_,test_],axis=0).reset_index()).describe()
# Out:
#            id         time        values
# count  2000.0  2000.000000  2.000000e+03
# mean     64.0    31.287780 -7.265299e-16
# std       0.0    18.086604  1.000250e+00
# min      64.0     0.000000 -1.639283e+00
# 25%      64.0    15.643890 -8.246416e-01
# 50%      64.0    31.287780 -7.692325e-02
# 75%      64.0    46.931670  7.706944e-01
# max      64.0    62.575560  2.219264e+00

# %%
df.plot()
# Out:
# <Axes: >

# %%
import statsmodels.api as sm

# %%
series_x = list(pd.concat([train_['values'], test_['values']], ignore_index=True))
date_rng = pd.date_range(start='1/1/2020', periods=2000)
series_x = pd.DataFrame(series_x, index=date_rng)
decomposition = sm.tsa.seasonal_decompose(series_x, model='additive')

plt.title('Tren dan Seasonalitas Data Variabel X')
plt.plot(series_x, label='data')
plt.plot(decomposition.trend, color='green', label='trend')
plt.plot(decomposition.seasonal, color='red', label='seasonal')
plt.legend(loc='upper right')
plt.show()

# %%
result = sm.tsa.adfuller(series_x)
# Menampilkan hasil uji ADF
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:')
for key, value in result[4].items():
    print(f'{key}: {value}')
# Out:
# ADF Statistic: -9.510277873069352
# p-value: 3.2634484008694047e-16
# Critical Values:
# 1%: -3.4336419856688276
# 5%: -2.862994217611322
# 10%: -2.567544164035933

# %% [markdown]
# **nolds**

# %%
import numpy as np
import nolds
largest_lyap = nolds.lyap_r(train_['values'])

entro = nolds.sampen(train_['values'])

print("lyapunov",largest_lyap)
print("entrophy",entro)
# Out:
# lyapunov 0.013892165969188942
# entrophy 0.4526177895647776

# %%
min_params = df[['values']].min()
max_params = df[['values']].max()

df[['values']] = (df[['values']] - min_params) / (max_params- min_params)

# %% [markdown]
# **split data becoming data train and test**

# %%
def df2series(df, cols):
    for i, col in enumerate(df[cols].columns):
        if i==0:
            series = darts.TimeSeries.from_dataframe(df, time_col=None, value_cols=col)
        else:
            series = series.stack(darts.TimeSeries.from_dataframe(df, time_col=None, value_cols=col))
    return series

cols = ['values'] # Silahkan rename jadi x, y, z


#data = df2series(df, cols)
all = df2series(df, cols)
#train, test = data.split_after(0.95)
train, test = all.split_after(0.95)
print('Data train',len(train), '\nData test',len(test))
# Out:
# Data train 1900
# Data test 100

# %%
plt.figure(figsize=(5,4))
train['values'].plot()
test['values'].plot()

# %% [markdown]
# ###RandomForest

# %%
def RF(data, model, pVal=0.05, n_jobs=8, verbose_=False, metric_='smape'):

    parameters = {
        "lags": list(range(2, 13)), # list(range(2, 13)),
        "output_chunk_length" : [10, 15, 20, 25],
        "n_estimators":[10, 25, 50], # list(range(10,110,10))
        "random_state":[0]
        }

    train, val = data.split_after(1-pVal)
    res = model.gridsearch(
        parameters=parameters,
        series=train,
        val_series=val,
        start=0.1,  # starting point in training set
        last_points_only=False,
        metric=getattr(metrics, metric_),
        reduction=np.mean,
        n_jobs=n_jobs,
        n_random_samples=None,# 0.99 % of full search space to evaluate
        verbose=verbose_,
    )
    return res

# %%
model, bestparams, bestMetric_ = RF(train, RandomForest)
print("BestParameters", bestparams)
print("bestMetric_", bestMetric_)
# ===================== Training, Forecast & BackTest for Cross Validation=============================
print("GridSearch Finished,Training Best Model ... ", flush=True)
model.fit(train)
forecast_ = model.predict(len(test))
smape_ = darts.metrics.smape(test, forecast_)
rmse_ = darts.metrics.rmse(test, forecast_)
print("Pada data test RMSE={}, sMAPE={} ".format(rmse_, smape_), flush=True)
# Out:
# BestParameters {'lags': 12, 'output_chunk_length': 25, 'n_estimators': 50, 'random_state': 0}
# bestMetric_ 13.39603535829365
# GridSearch Finished,Training Best Model ...
# Pada data test RMSE=0.15062717791235494, sMAPE=32.382298587631496

# %%
test['values'].plot(label='aktual x')

forecast_['values'].plot(label='Forecast')
plt.show()

# %% [markdown]
# cross validation

# %%
# ===================== Forecast & BackTest for Cross Validation=============================
print("Starting Backtest (Expanding Window) Cross Validation ...", flush=True)
model, bestparams, bestMetric_ = RF(train, RandomForest)
# Out:
# Starting Backtest (Expanding Window) Cross Validation ...

# %%
print("Starting Backtest (Expanding Window) Cross Validation ...", flush=True)
backTest = model.historical_forecasts(all, start=.9, forecast_horizon=10)

print("Backtest Finished", flush=True)
# ===================== Evaluate =============================
# Out:
# Starting Backtest (Expanding Window) Cross Validation ...
# Backtest Finished

# %%
print(len(backTest))
# Out:
# 192

# %%
all[-len(backTest)-100:].plot()
backTest.plot(label='backtest (n=10)')

# %%
smape_ = darts.metrics.smape(all, backTest)
rmse_ = darts.metrics.rmse(all, backTest)
print("Hasil Cross Validasi RMSE={}, sMAPE={} ".format(rmse_, smape_), flush=True)
# Out:
# Hasil Cross Validasi RMSE=0.05260120342176886, sMAPE=10.946125469508104

# %% [markdown]
# ### NBEATS

# %%
from darts.models import NBEATSModel
def NB(data, model, pVal=0.05, n_jobs=8, verbose_=False, metric_='smape'):
    parameters = {
                  'input_chunk_length':[5],
                  'output_chunk_length':[5],
                  "random_state":[0],
    }

    train, val = data.split_after(1-pVal)
    res = model.gridsearch(
        parameters=parameters,
        series=train,
        val_series=val,
        start=0.1,  # starting point in training set
        last_points_only=False,
        metric=getattr(metrics, metric_),
        reduction=np.mean,
        n_jobs=n_jobs,
        n_random_samples=None,# 0.99 % of full search space to evaluate
        verbose=verbose_,
    )
    return res

# %%
model, bestparams, bestMetric_ = NB(train, NBEATSModel)
print("BestParameters", bestparams)
print("bestMetric_", bestMetric_)
# ===================== Training, Forecast & BackTest for Cross Validation=============================
print("GridSearch Finished,Training Best Model ... ", flush=True)
model.fit(train)
forecast_ = model.predict(len(test))
smape_ = darts.metrics.smape(test, forecast_)
rmse_ = darts.metrics.rmse(test, forecast_)
print("Pada data test RMSE={}, sMAPE={} ".format(rmse_, smape_), flush=True)
# Out:
# BestParameters {'input_chunk_length': 5, 'output_chunk_length': 5, 'random_state': 0}
# bestMetric_ 60.96873183508795
# GridSearch Finished,Training Best Model ...
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]
# Pada data test RMSE=0.3111924592081083, sMAPE=48.3256105708932

# %%
test['values'].plot(label='aktual x')

forecast_['values'].plot(label='Forecast')
plt.show()

# %% [markdown]
# cross validation

# %%
# ===================== Forecast & BackTest for Cross Validation=============================
print("Starting Backtest (Expanding Window) Cross Validation ...", flush=True)
model, bestparams, bestMetric_ = NB(train, NBEATSModel)
# Out:
# Starting Backtest (Expanding Window) Cross Validation ...

# %%
print("Starting Backtest (Expanding Window) Cross Validation ...", flush=True)
backTest = model.historical_forecasts(all, start=.9, forecast_horizon=10)

print("Backtest Finished", flush=True)
# ===================== Evaluate =============================
# Out:
# Starting Backtest (Expanding Window) Cross Validation ...
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]

# %%
print(len(backTest))

# %%
all[-len(backTest)-100:].plot()
backTest.plot(label='backtest (n=10)')

# %%
smape_ = darts.metrics.smape(all, backTest)
rmse_ = darts.metrics.rmse(all, backTest)
print("Hasil Cross Validasi RMSE={}, sMAPE={} ".format(rmse_, smape_), flush=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-33bb4e575054> in <cell line: 1>()
# ----> 1 smape_ = darts.metrics.smape(all, backTest)
#       2 rmse_ = darts.metrics.rmse(all, backTest)
#       3 print("Hasil Cross Validasi RMSE={}, sMAPE={} ".format(rmse_, smape_), flush=True)
#
# NameError: name 'darts' is not defined

# %% [markdown]
# ###exponential smoothing

# %%
from darts.models import ExponentialSmoothing
from darts.utils.utils import ModelMode, SeasonalityMode

def ES(data, model, pVal=0.05, n_jobs=8, verbose_=False, metric_='smape'):

    parameters = {
        "trend": [ModelMode.ADDITIVE,None],#ModelMode.MULTIPLICATIVE,
        "damped" : [False],#True
        "seasonal" : [SeasonalityMode.ADDITIVE,None],#SeasonalityMode.MULTIPLICATIVE,
        "random_state":[0],
    }

    train, val = data.split_after(1-pVal)
    res = model.gridsearch(
        parameters=parameters,
        series=train,
        val_series=val,
        start=0.1,  # starting point in training set
        last_points_only=False,
        metric=getattr(metrics, metric_),
        reduction=np.mean,
        n_jobs=n_jobs,
        n_random_samples=None,# 0.99 % of full search space to evaluate
        verbose=verbose_,
    )
    return res

# %%
model, bestparams, bestMetric = ES(train, ExponentialSmoothing)
print("BestParameters", bestparams)
print("bestMetric_", bestMetric_)
# ===================== Training, Forecast & BackTest for Cross Validation=============================
print("GridSearch Finished,Training Best Model ... ", flush=True)
model.fit(train)
forecast = model.predict(len(test))
smape_ = darts.metrics.smape(test, forecast)
rmse_ = darts.metrics.rmse(test, forecast)
print("Pada data test RMSE={}, sMAPE={} ".format(rmse_, smape_), flush=True)
# Out:
# BestParameters {'trend': None, 'damped': False, 'seasonal': None, 'random_state': 0}
# bestMetric_ 13.39603535829365
# GridSearch Finished,Training Best Model ...
# Pada data test RMSE=0.2436835161016286, sMAPE=43.58413082533159

# %%
test['values'].plot(label='aktual x')

forecast_['values'].plot(label='Forecast')
plt.show()

# %% [markdown]
# **cross validation**

# %%
# ===================== Forecast & BackTest for Cross Validation=============================
print("Starting Backtest (Expanding Window) Cross Validation ...", flush=True)
model, bestparams, bestMetric_ = ES(train, ExponentialSmoothing)
# Out:
# Starting Backtest (Expanding Window) Cross Validation ...

# %%
print("Starting Backtest (Expanding Window) Cross Validation ...", flush=True)
backTest = model.historical_forecasts(all, start=.9, forecast_horizon=10)

print("Backtest Finished", flush=True)
# ===================== Evaluate =============================
# Out:
# Starting Backtest (Expanding Window) Cross Validation ...
# Backtest Finished

# %%
print(len(backTest))
# Out:
# 192

# %%
all[-len(backTest)-100:].plot()
backTest.plot(label='backtest (n=10)')

# %%
smape_ = darts.metrics.smape(all, backTest)
rmse_ = darts.metrics.rmse(all, backTest)
print("Hasil Cross Validasi RMSE={}, sMAPE={} ".format(rmse_, smape_), flush=True)
# Out:
# Hasil Cross Validasi RMSE=0.3232649916534424, sMAPE=68.36853925883611

# %% [markdown]
# ### 4Theta

# %%
from darts.models import FourTheta
from darts.utils.utils import TrendMode,ModelMode,SeasonalityMode
def fort(data, model, pVal=0.05, n_jobs=8, verbose_=False, metric_='smape'):

    parameters = {
        "theta": list(range(0,2)),
        "seasonality_period" : [None],#True
        "season_mode" : [SeasonalityMode.ADDITIVE,SeasonalityMode.NONE],#SeasonalityMode.MULTIPLICATIVE,
        "model_mode" : [ModelMode.ADDITIVE],
        "trend_mode" : [TrendMode.EXPONENTIAL,TrendMode.LINEAR],
        'normalization' : [True,False],
        #"random_state":[0],
    }

    train, val = data.split_after(1-pVal)
    res = model.gridsearch(
        parameters=parameters,
        series=train,
        val_series=val,
        start=0.1,  # starting point in training set
        last_points_only=False,
        metric=getattr(metrics, metric_),
        reduction=np.mean,
        n_jobs=n_jobs,
        n_random_samples=None,# 0.99 % of full search space to evaluate
        verbose=verbose_,
    )
    return res

# %%
model, bestparams, bestMetric = fort(train, FourTheta)
print("BestParameters", bestparams)
print("bestMetric_", bestMetric_)
# ===================== Training, Forecast & BackTest for Cross Validation=============================
print("GridSearch Finished,Training Best Model ... ", flush=True)
model.fit(train)
forecast= model.predict(len(test))
smape_ = darts.metrics.smape(test, forecast)
rmse_ = darts.metrics.rmse(test, forecast)
print("Pada data test RMSE={}, sMAPE={} ".format(rmse_, smape_), flush=True)
# Out:
# BestParameters {'theta': 0, 'seasonality_period': None, 'season_mode': <SeasonalityMode.ADDITIVE: 'additive'>, 'model_mode': <ModelMode.ADDITIVE: 'additive'>, 'trend_mode': <TrendMode.EXPONENTIAL: 'exponential'>, 'normalization': True}
# bestMetric_ 102.30026868118074
# GridSearch Finished,Training Best Model ...
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# Pada data test RMSE=0.26250233768098313, sMAPE=44.38577817634883

# %%
test['values'].plot(label='aktual x')
forecast['values'].plot(label='Forecast')
plt.show()

# %% [markdown]
# **cross validation**

# %%
# ===================== Forecast & BackTest for Cross Validation=============================
print("Starting Backtest (Expanding Window) Cross Validation ...", flush=True)
model, bestparams, bestMetric = fort(train, FourTheta)
# Out:
# Starting Backtest (Expanding Window) Cross Validation ...

# %%
print("Starting Backtest (Expanding Window) Cross Validation ...", flush=True)
backTest = model.historical_forecasts(all, start=.9, forecast_horizon=10)

print("Backtest Finished", flush=True)
# ===================== Evaluate =============================
# Out:
# Starting Backtest (Expanding Window) Cross Validation ...
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# Backtest Finished

# %%
print(len(backTest))
# Out:
# 192

# %%
all[-len(backTest)-100:].plot()
backTest.plot(label='backtest (n=10)')

# %%
smape_ = darts.metrics.smape(all, backTest)
rmse_ = darts.metrics.rmse(all, backTest)
print("Hasil Cross Validasi RMSE={}, sMAPE={} ".format(rmse_, smape_), flush=True)
# Out:
# Hasil Cross Validasi RMSE=0.27290218039612224, sMAPE=51.82883441622364

# %% [markdown]
# ###ARIMA

# %%
#print(list(range(0,3)))

# %%
def AR(data, model, pVal=0.05, n_jobs=8, verbose_=False, metric_='smape'):
    parameters = {
        "p": [3,5],#list(range(2, 12)),
        "d" : [0,1],#list(range(0, 2)),
        "q" : [3,5],#list(range(2, 12)),
        "random_state":[0],
    }

    train, val = data.split_after(1-pVal)
    res = model.gridsearch(
        parameters=parameters,
        series=train,
        val_series=val,
        start=0.1,  # starting point in training set
        last_points_only=False,
        metric=getattr(metrics, metric_),
        reduction=np.mean,
        n_jobs=n_jobs,
        n_random_samples=None,# 0.99 % of full search space to evaluate
        verbose=verbose_,
    )
    return res

# %%
model, bestparams, bestMetric_ = AR(train, ARIMA)
print("BestParameters", bestparams)
print("bestMetric_", bestMetric_)
# ===================== Training, Forecast & BackTest for Cross Validation=============================
print("GridSearch Finished,Training Best Model ... ", flush=True)
model.fit(train)
forecast_ = model.predict(len(test))
smape_ = darts.metrics.smape(test, forecast_)
rmse_ = darts.metrics.rmse(test, forecast_)
print("Pada data test RMSE={}, sMAPE={} ".format(rmse_, smape_), flush=True)
# Out:
# BestParameters {'p': 3, 'd': 1, 'q': 5, 'random_state': 0}
# bestMetric_ 52.07842547491563
# GridSearch Finished,Training Best Model ...
# Pada data test RMSE=0.23223625937232611, sMAPE=40.8784566877643

# %%
test['values'].plot(label='aktual x')

forecast_['values'].plot(label='Forecast')
plt.show()

# %% [markdown]
# cross validation

# %%
# ===================== Forecast & BackTest for Cross Validation=============================
print("Starting Backtest (Expanding Window) Cross Validation ...", flush=True)
model, bestparams, bestMetric_ = AR(train, ARIMA)
# Out:
# Starting Backtest (Expanding Window) Cross Validation ...

# %%
print("Starting Backtest (Expanding Window) Cross Validation ...", flush=True)
backTest = model.historical_forecasts(all, start=.9, forecast_horizon=10)

print("Backtest Finished", flush=True)
# ===================== Evaluate =============================
# Out:
# Starting Backtest (Expanding Window) Cross Validation ...
# Backtest Finished

# %%
print(len(backTest))
# Out:
# 192

# %%
all[-len(backTest)-100:].plot()
backTest.plot(label='backtest (n=10)')

# %%
smape_ = darts.metrics.smape(all, backTest)
rmse_ = darts.metrics.rmse(all, backTest)
print("Hasil Cross Validasi RMSE={}, sMAPE={} ".format(rmse_, smape_), flush=True)
# Out:
# Hasil Cross Validasi RMSE=0.22015740915073256, sMAPE=47.62748274179384

# %% [markdown]
# ###RegresiEnsemble grid cv

# %%
from darts.models import NBEATSModel,FourTheta
m_4t = FourTheta(season_mode=SeasonalityMode.ADDITIVE, model_mode=ModelMode.ADDITIVE)

m_nb = NBEATSModel(input_chunk_length=24,
                    output_chunk_length=12)
m_RF = RandomForest(lags= 12, output_chunk_length= 25, n_estimators= 50, random_state= 0)
m_AR = ARIMA(p=9, d=0, q=7, random_state=0)
m_es = ExponentialSmoothing(trend=None, seasonal=None, damped=False, random_state=0)
models = [#m_RF ,
          #m_AR ,
          m_es,
          #m_nb
          m_4t
          ]

# %%
from darts.models import LinearRegressionModel
def RE(data, model, pVal=0.05, n_jobs=8, verbose_=False, metric_='smape'):

    parameters = {
        "forecasting_models": [models
            #(RandomForest(lags= 12, output_chunk_length= 25, n_estimators= 50, random_state= 0), #lags': 12, 'output_chunk_length': 25, 'n_estimators': 50, 'random_state': 0
             #                  ARIMA(p=9, d=0, q=7, random_state=0)),
           #                     (ARIMA(p=9, d=0, q=7, random_state=0)
           #                     ExponentialSmoothing(trend=None, seasonal=None, damped=False, random_state=0)),
                               ],
        "regression_train_n_points": [6], #12#list(range(2,13)),
        #"regression_model" : [LinearRegressionModel(fit_intercept=False)],
        #"random_state":[0],
    }

    train, val = data.split_after(1-pVal)
    res = model.gridsearch(
        parameters=parameters,
        series=train,
        val_series=val,
        start=0.1,  # starting point in training set
        last_points_only=False,
        metric=getattr(metrics, metric_),
        reduction=np.mean,
        n_jobs=n_jobs,
        n_random_samples=None,# 0.99 % of full search space to evaluate
        verbose=verbose_,
    )
    return res

# %%
model, bestparams, bestMetric_ = RE(train, RegressionEnsembleModel)
print("BestParameters", bestparams)
print("bestMetric_", bestMetric_)
# ===================== Training, Forecast & BackTest for Cross Validation=============================
print("GridSearch Finished,Training Best Model ... ", flush=True)
model.fit(train)
forecast_ = model.predict(len(test))
smape_ = darts.metrics.smape(test, forecast_)
rmse_ = darts.metrics.rmse(test, forecast_)
print("Pada data test RMSE={}, sMAPE={} ".format(rmse_, smape_), flush=True)
# Out:
# BestParameters {'forecasting_models': [ExponentialSmoothing(trend=None, damped=False, seasonal=None, seasonal_periods=None, random_state=0), FourTheta(theta=2, seasonality_period=None, season_mode=SeasonalityMode.ADDITIVE, model_mode=ModelMode.ADDITIVE, trend_mode=TrendMode.LINEAR, normalization=True)], 'regression_train_n_points': 6}
# bestMetric_ 99.12209890899886
# GridSearch Finished,Training Best Model ...
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# WARNING:darts.models.forecasting.theta:Time series has negative values. Fallback to additive and linear model
# Pada data test RMSE=0.2976094542154944, sMAPE=46.30103879384485

# %%
test['values'].plot(label='aktual x')

forecast_['values'].plot(label='Forecast')
plt.show()

# %% [markdown]
# **cross validation**

# %%
# ===================== Forecast & BackTest for Cross Validation=============================
print("Starting Backtest (Expanding Window) Cross Validation ...", flush=True)
model, bestparams, bestMetric_ = RE(train, RegressionEnsembleModel)
# Out:
# Starting Backtest (Expanding Window) Cross Validation ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-e170deb823b0> in <cell line: 3>()
#       1 # ===================== Forecast & BackTest for Cross Validation=============================
#       2 print("Starting Backtest (Expanding Window) Cross Validation ...", flush=True)
# ----> 3 model, bestparams, bestMetric_ = RE(train, RegressionEnsembleModel)
#
# <ipython-input-124-36b6642fef22> in RE(data, model, pVal, n_jobs, verbose_, metric_)
#      15
#      16     train, val = data.split_after(1-pVal)
# ---> 17     res = model.gridsearch(
#      18         parameters=parameters,
#      19         series=train,
#
# /usr/local/lib/python3.10/dist-packages/darts/models/forecasting/forecasting_model.py in gridsearch(model_class, parameters, series, past_covariates, future_covariates, forecast_horizon, stride, start, last_points_only, show_warnings, val_series, use_fitted_values, metric, reduction, verbose, n_jobs, n_random_samples)
#    1518             return float(error)
#    1519
# -> 1520         errors: List[float] = _parallel_apply(
#    1521             iterator, _evaluate_combination, n_jobs, {}, {}
#    1522         )
#
# /usr/local/lib/python3.10/dist-packages/darts/utils/utils.py in _parallel_apply(iterator, fn, n_jobs, fn_args, fn_kwargs)
#     331     """
#     332
# --> 333     returned_data = Parallel(n_jobs=n_jobs)(
#     334         delayed(fn)(*sample, *fn_args, **fn_kwargs) for sample in iterator
#     335     )
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# /usr/local/lib/python3.10/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     456                     raise CancelledError()
#     457                 elif self._state == FINISHED:
# --> 458                     return self.__get_result()
#     459                 else:
#     460                     raise TimeoutError()
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __get_result(self)
#     401         if self._exception:
#     402             try:
# --> 403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
#
# ValueError: Cannot instantiate EnsembleModel with trained/fitted models. Consider resetting all models with `my_model.untrained_model()`

# %%
print("Starting Backtest (Expanding Window) Cross Validation ...", flush=True)
backTest = model.historical_forecasts(all, start=.9, forecast_horizon=10)

print("Backtest Finished", flush=True)
# ===================== Evaluate =============================

# %%
print(len(backTest))

# %%
all[-len(backTest)-100:].plot()
backTest.plot(label='backtest (n=10)')

# %%
smape_ = darts.metrics.smape(all, backTest)
rmse_ = darts.metrics.rmse(all, backTest)
print("Hasil Cross Validasi RMSE={}, sMAPE={} ".format(rmse_, smape_), flush=True)

# %% [markdown]
# ### Regresi Ensemble non grid cv

# %%
from darts.metrics import smape, mape, mase, mae, mse, ope, r2_score, rmse, rmsle
from darts.utils.statistics import check_seasonality, plot_acf, plot_residuals_analysis
from darts.dataprocessing.transformers.boxcox import BoxCox
import time

# %%
# compute accuracy metrics and processing time

def accuracy_metrics(act, forecast, resid):#, t_star
    sr = resid.pd_series()
    sa = act.pd_series()
    n_act = len(act)
    res_mape = mape(act, forecast)
    res_smape = smape(act, forecast)
    res_mae = mae(act, forecast)
    res_r2 = r2_score(act, forecast)
    res_rmse = rmse(act, forecast)
    res_rmsle = rmsle(act, forecast)
    res_pe = sr / sa
    res_rmspe = np.sqrt(np.sum(res_pe**2) / n_act)    # root mean square percentage error

    #res_time = time.perf_counter() - t_start

    res_mean = np.mean(sr)
    res_std = np.std(sr)                               # std error of the model = std deviation of the noise
    res_se = res_std / np.sqrt(n_act)                  # std error in estimating the mean
    res_sefc = np.sqrt(res_std + res_se**2)            # std error of the forecast

    res_accuracy = {"SMAPE" : res_smape,"MAPE":res_mape,"RMSE":res_rmse, "-R squared":-res_r2,
        "se": res_sefc} #, "time":res_time
    return res_accuracy

# %%
## fit the chosen forecaster model and compute predictions

def eval_model(model):
    #t_start =  time.perf_counter()
    strmodel = str(model)[:30]
    print("beginning: " + strmodel)


    # fit the model and compute predictions
    n_val = len(test)
    res = model.fit(train)
    forecast = model.predict(n_val)


    # for naive forecast, concatenate seasonal fc with drift fc
    ##if model == m_stat:
    ##    if is_seasonal:
    ##        fc_drift = forecast
      ##      modelS = NaiveSeasonal(K=mseas)
       ##     modelS.fit(train)
         #### forecast = fc_drift + fc_seas - train.last_value()


    resid = forecast - test
    res_accuracy = accuracy_metrics(test, forecast, resid)#, t_start


    results = [forecast, res_accuracy]

    print("completed: " + strmodel + ":" + str(res_accuracy["time"]) + " sec")
    return results

# %% [markdown]
# #### Ensemble RF dan NBEATS

# %%
models=[
        #ARIMA(p = 3, d= 1, q=5,random_state=0),
        #ExponentialSmoothing(trend=None, damped=False, seasonal=None, random_state=0),
        RandomForest(lags= 12, output_chunk_length= 25, n_estimators= 50, random_state= 0),
        NBEATSModel(input_chunk_length=5,output_chunk_length=5,random_state=0),
        FourTheta(theta=0,seasonality_period = None, season_mode = SeasonalityMode.ADDITIVE, model_mode = ModelMode.ADDITIVE,trend_mode=TrendMode.EXPONENTIAL, normalization=True)
]

# %%
# ensemble forecast evaluation function:
# the eval function calls the methods contained in the list 'models'

def ensemble_eval(train, test, models):
    #t_start =  time.perf_counter()
    n_train = 12                # use 50 observation to train the ensemble model
    n_val = len(test)            # forecast as many periods as are in the valuation dataset


    # compute predictions
    # ensemble_model = RegressionEnsembleModel(forecasting_models=models, regression_train_n_points=n_train)
    # new Jan 022: RegressionEnsembleModel class no longer accepts as argument the list "models" of previously instantiated models
    # instead, explicitly list each of the forecast methods
    ensemble_model = RegressionEnsembleModel(
                                forecasting_models=[
                                    #ARIMA(p = 3, d= 1, q=5,random_state=0),
                                    #ExponentialSmoothing(trend=None, damped=False, seasonal=None, random_state=0),
                                    RandomForest(lags= 12, output_chunk_length= 25, n_estimators= 50, random_state= 0),
                                    NBEATSModel(input_chunk_length=5,output_chunk_length=5,random_state=0),
                                    #FourTheta(theta=0,seasonality_period = None, season_mode = SeasonalityMode.ADDITIVE, model_mode = ModelMode.ADDITIVE,trend_mode=TrendMode.EXPONENTIAL, normalization=True)
                                                        ],
                                regression_train_n_points=12,
                                #regression_model = RandomForest(lags=None,lags_future_covariates = [0], lags_past_covariates = None, output_chunk_length=12 ,add_encoders=None, n_estimators= 50, random_state= 0 )
                                )


    ensemble_model.fit(train)
    forecast = ensemble_model.predict(n_val)
    resid = forecast - test


    res_accuracy = accuracy_metrics(test, forecast, resid)#,t_start


    # plot the ensemble forecast
    #data.plot(label="actual") #kalau mau liat seluruh data
    test.plot(label="actual") # kalau mau liat perbandingan data test dgn forecast
    forecast.plot(label="Ensemble forecast")
    plt.title("SMAPE = {:.2f}%".format(res_accuracy["SMAPE"]))
    plt.legend();


    results = [forecast, res_accuracy]
    return results

# %%
# call the ensemble eval function with all 5 forecasters:

# column headers and model selection:
col_heads = ["ARIMA",  "Exponential Smoothing", "avg", "Ensemble"]
models2 = models

# run the ensemble forecast
print("Ensemble of all 2 forecasters:")
res_ensemble = ensemble_eval(train,test, models2)
# Out:
# Ensemble of all 2 forecasters:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.0 M
# ---------------------------------------------------
# 6.0 M     Trainable params
# 1.3 K     Non-trainable params
# 6.0 M     Total params
# 24.185    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %% [markdown]
# #### Ensemble

# %%
models_=[
        #ARIMA(p = 3, d= 1, q=5,random_state=0),
        #ExponentialSmoothing(trend=None, damped=False, seasonal=None, random_state=0),
        RandomForest(lags= 12, output_chunk_length= 25, n_estimators= 50, random_state= 0),
        #NBEATSModel(input_chunk_length=5,output_chunk_length=5,random_state=0),
        FourTheta(theta=0,seasonality_period = None, season_mode = SeasonalityMode.ADDITIVE, model_mode = ModelMode.ADDITIVE,trend_mode=TrendMode.EXPONENTIAL, normalization=True)
]

# %%
# ensemble forecast evaluation function:
# the eval function calls the methods contained in the list 'models'

def ensemble_eval(train, test, models):
    #t_start =  time.perf_counter()
    n_train = 12                # use 50 observation to train the ensemble model
    n_val = len(test)            # forecast as many periods as are in the valuation dataset


    # compute predictions
    # ensemble_model = RegressionEnsembleModel(forecasting_models=models, regression_train_n_points=n_train)
    # new Jan 022: RegressionEnsembleModel class no longer accepts as argument the list "models" of previously instantiated models
    # instead, explicitly list each of the forecast methods
    ensemble_model = RegressionEnsembleModel(
                                forecasting_models=[
                                    #ARIMA(p = 3, d= 1, q=5,random_state=0),
                                    #ExponentialSmoothing(trend=None, damped=False, seasonal=None, random_state=0),
                                    RandomForest(lags= 12, output_chunk_length= 25, n_estimators= 50, random_state= 0),
                                    #NBEATSModel(input_chunk_length=5,output_chunk_length=5,random_state=0),
                                    FourTheta(theta=0,seasonality_period = None, season_mode = SeasonalityMode.ADDITIVE, model_mode = ModelMode.ADDITIVE,trend_mode=TrendMode.EXPONENTIAL, normalization=True)
                                                        ],
                                regression_train_n_points=12,
                                #regression_model = RandomForest(lags=None,lags_future_covariates = [0], lags_past_covariates = None, output_chunk_length=12 ,add_encoders=None, n_estimators= 50, random_state= 0 )
                                )


    ensemble_model.fit(train)
    forecast = ensemble_model.predict(n_val)
    resid = forecast - test


    res_accuracy = accuracy_metrics(test, forecast, resid)#,t_start


    # plot the ensemble forecast
    #data.plot(label="actual") #kalau mau liat seluruh data
    test.plot(label="actual") # kalau mau liat perbandingan data test dgn forecast
    forecast.plot(label="Ensemble forecast")
    plt.title("SMAPE = {:.2f}%".format(res_accuracy["SMAPE"]))
    plt.legend();


    results = [forecast, res_accuracy]
    return results

# %%
# call the ensemble eval function with all 5 forecasters:

# column headers and model selection:
col_heads = ["ARIMA",  "Exponential Smoothing", "avg", "Ensemble"]
models2 = models_

# run the ensemble forecast
print("Ensemble of all 2 forecasters:")
res_ensemble = ensemble_eval(train,test, models2)
# Out:
# ERROR:darts.models.forecasting.ensemble_model:ValueError: All models must be of the same type: either GlobalForecastingModel, or LocalForecastingModel.
# Ensemble of all 2 forecasters:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-c09b783d8ce0> in <cell line: 9>()
#       7 # run the ensemble forecast
#       8 print("Ensemble of all 2 forecasters:")
# ----> 9 res_ensemble = ensemble_eval(train,test, models2)
#
# <ipython-input-99-551ec8a8a79b> in ensemble_eval(train, test, models)
#      12     # new Jan 022: RegressionEnsembleModel class no longer accepts as argument the list "models" of previously instantiated models
#      13     # instead, explicitly list each of the forecast methods
# ---> 14     ensemble_model = RegressionEnsembleModel(
#      15                                 forecasting_models=[
#      16                                     #ARIMA(p = 3, d= 1, q=5,random_state=0),
#
# /usr/local/lib/python3.10/dist-packages/darts/models/forecasting/forecasting_model.py in __call__(cls, *args, **kwargs)
#     101
#     102         # 6) call model
# --> 103         return super().__call__(**all_params)
#     104
#     105
#
# /usr/local/lib/python3.10/dist-packages/darts/models/forecasting/regression_ensemble_model.py in __init__(self, forecasting_models, regression_train_n_points, regression_model)
#      49             Default: ``darts.model.LinearRegressionModel(fit_intercept=False)``
#      50         """
# ---> 51         super().__init__(forecasting_models)
#      52         if regression_model is None:
#      53             regression_model = LinearRegressionModel(
#
# /usr/local/lib/python3.10/dist-packages/darts/models/forecasting/ensemble_model.py in __init__(self, models)
#      45         )
#      46
# ---> 47         raise_if_not(
#      48             is_local_ensemble or self.is_global_ensemble,
#      49             "All models must be of the same type: either GlobalForecastingModel, or LocalForecastingModel.",
#
# /usr/local/lib/python3.10/dist-packages/darts/logging.py in raise_if_not(condition, message, logger)
#      76     if not condition:
#      77         logger.error("ValueError: " + message)
# ---> 78         raise ValueError(message)
#      79
#      80
#
# ValueError: All models must be of the same type: either GlobalForecastingModel, or LocalForecastingModel.
